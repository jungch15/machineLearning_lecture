jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Albrecht_Du╠êrer_201.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Vasiliy_Kandinskiy_52.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Pablo_Picasso_61.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Frida_Kahlo_12.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Rembrandt_8.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Marc_Chagall_176.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Titian_174.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Paul_Klee_173.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Vincent_van_Gogh_164.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Peter_Paul_Rubens_124.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Vasiliy_Kandinskiy_50.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Albrecht_Du╠êrer_268.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Mikhail_Vrubel_165.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Paul_Gauguin_180.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Piet_Mondrian_31.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Vasiliy_Kandinskiy_43.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Edgar_Degas_329.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Pieter_Bruegel_88.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Alfred_Sisley_185.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Paul_Gauguin_195.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Vincent_van_Gogh_255.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Raphael_35.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Pablo_Picasso_108.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Giotto_di_Bondone_18.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Vincent_van_Gogh_322.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Paul_Klee_142.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Rembrandt_190.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Camille_Pissarro_17.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Diego_Rivera_67.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Giotto_di_Bondone_96.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Vincent_van_Gogh_11.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Hieronymus_Bosch_18.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Diego_Rivera_27.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Peter_Paul_Rubens_56.jpg
# /kaggle/input/best-artworks-of-all-time/resized/resized/Francisco_Goya_206.jpg
# ...
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_127.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_186.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_185.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_147.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_54.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_87.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_125.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_152.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_170.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_15.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_39.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_45.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_101.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_155.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_174.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_27.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_156.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_178.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_92.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_19.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_38.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_49.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_83.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_130.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_108.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_89.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_12.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_94.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_137.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_159.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_44.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_145.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_99.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_188.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_42.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_97.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_172.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Amedeo_Modigliani/Amedeo_Modigliani_25.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_90.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_17.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_9.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_106.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_32.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_12.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_79.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_127.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_8.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_73.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_69.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_88.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_131.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_121.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_64.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_132.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_56.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_101.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_84.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_126.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_66.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_41.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_31.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_40.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_52.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_65.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_77.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_92.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_85.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_57.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_29.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_14.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_102.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_119.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_63.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_53.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_107.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_58.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_20.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_68.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_70.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_23.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_94.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_26.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_83.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_72.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_44.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_120.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_95.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_105.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_37.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_97.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_115.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_34.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_10.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_45.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_86.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_5.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_116.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_110.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_80.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_113.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_130.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_59.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_50.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_122.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_128.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_98.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_111.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_48.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_75.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_21.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_76.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_81.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_36.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_117.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_46.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_124.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_123.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_99.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_100.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_112.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_39.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_54.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_104.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_28.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_62.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_27.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_87.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_89.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_82.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_11.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_74.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_3.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_91.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_22.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_133.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_33.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_61.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_7.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_24.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_103.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_1.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_60.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_43.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_15.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_16.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_25.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_129.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_78.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_118.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_55.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_47.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_134.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_13.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_6.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_42.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_18.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_2.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_114.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_49.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_4.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_30.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_93.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_19.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_67.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_109.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_38.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_51.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_71.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_108.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_125.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_96.jpg
# /kaggle/input/best-artworks-of-all-time/images/images/Pieter_Bruegel/Pieter_Bruegel_35.jpg

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import os
from tqdm import tqdm, tqdm_notebook
import random

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.applications import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from numpy.random import seed
from keras import regularizers
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## data preprocessing

# %%
data_dir = '/kaggle/input/best-artworks-of-all-time/'
data = pd.read_csv('/kaggle/input/best-artworks-of-all-time/artists.csv')

# %%
genre_df = data.groupby('genre')['paintings'].sum().reset_index(name='Count')

# %%
genre_df[genre_df['Count']>=150].reset_index().sort_values(by='Count', ascending = False)
# Out:
#     index                                    genre  Count
# 7      10                            Impressionism   1370
# 11     16                       Post-Impressionism   1048
# 9      14                     Northern Renaissance    680
# 0       1                                  Baroque    586
# 1       3                                   Cubism    439
# 13     22                              Romanticism    388
# 17     30             Symbolism,Post-Impressionism    311
# 12     17                              Primitivism    309
# 5       8                         High Renaissance    301
# 8      11         Impressionism,Post-Impressionism    277
# 6       9               High Renaissance,Mannerism    255
# 14     25                               Surrealism    241
# 15     26                 Surrealism,Impressionism    194
# 3       5                            Expressionism    193
# 4       7  Expressionism,Abstractionism,Surrealism    188
# 10     15                                  Pop Art    181
# 16     27                                Symbolism    171
# 2       4                        Early Renaissance    164

# %%
genre = np.array(genre_df[genre_df['Count']>=200].reset_index()['genre'])
len(genre)
# Out:
# 12

# %%
genre = ['Baroque', 'Cubism', 'High Renaissance',
        'Impressionism', 'Expressionism', 'Northern Renaissance', 'Pop Art', 
         'Post-Impressionism', 'Primitivism', 'Romanticism', 'Surrealism', 'Symbolism']

# %%
from collections import defaultdict

genre_artist = defaultdict(list)
for g in genre:
    for i in range(len(data)):
        if data['genre'].iloc[i] == g:
            genre_artist[g].append(data['name'].iloc[i])

# %%
genre_artist
# Out:
# defaultdict(list,
#             {'Baroque': ['Peter Paul Rubens',
#               'Caravaggio',
#               'Diego Velazquez',
#               'Rembrandt'],
#              'Cubism': ['Pablo Picasso'],
#              'High Renaissance': ['Leonardo da Vinci',
#               'Raphael',
#               'Michelangelo'],
#              'Impressionism': ['Claude Monet',
#               'Pierre-Auguste Renoir',
#               'Alfred Sisley',
#               'Edgar Degas'],
#              'Expressionism': ['Amedeo Modigliani'],
#              'Northern Renaissance': ['Hieronymus Bosch',
#               'Albrecht Dürer',
#               'Pieter Bruegel',
#               'Jan van Eyck'],
#              'Pop Art': ['Andy Warhol'],
#              'Post-Impressionism': ['Vincent van Gogh',
#               'Henri de Toulouse-Lautrec',
#               'Paul Cezanne',
#               'Georges Seurat'],
#              'Primitivism': ['Marc Chagall', 'Henri Rousseau'],
#              'Romanticism': ['Francisco Goya',
#               'William Turner',
#               'Eugene Delacroix'],
#              'Surrealism': ['Salvador Dali', 'Joan Miro'],
#              'Symbolism': ['Mikhail Vrubel']})

# %%
# !mkdir image_dir
for g in genre:
    gg = g.replace(" ", "_")
    print(gg)
    # !mkdir image_dir/$gg
    for i in genre_artist[g]:
        name = i.replace(" ", "_")
        if name == 'Albrecht_Dürer':
            # !cp -r /kaggle/input/best-artworks-of-all-time/images/images/Albrecht_Du╠êrer/* 'image_dir/'$gg
        else:
            # !cp -r '/kaggle/input/best-artworks-of-all-time/images/images/'$name/* 'image_dir/'$gg
# Out:
# Baroque
# Cubism
# High_Renaissance
# Impressionism
# Expressionism
# Northern_Renaissance
# Pop_Art
# Post-Impressionism
# Primitivism
# Romanticism
# Surrealism
# Symbolism

# %%
# !mv image_dir/High_Renaissance 'image_dir/High Renaissance'
# !mv image_dir/Northern_Renaissance 'image_dir/Northern Renaissance'
# !mv image_dir/Pop_Art 'image_dir/Pop Art'

# %%
genre_df = data.groupby('genre')['paintings'].sum().reset_index(name='Count')
genre_df = genre_df[genre_df['genre'].isin(genre)].reset_index()
genre_df = genre_df.drop(['index'],axis = 1)
genre_df
# Out:
#                    genre  Count
# 0                Baroque    586
# 1                 Cubism    439
# 2          Expressionism    193
# 3       High Renaissance    301
# 4          Impressionism   1370
# 5   Northern Renaissance    680
# 6                Pop Art    181
# 7     Post-Impressionism   1048
# 8            Primitivism    309
# 9            Romanticism    388
# 10            Surrealism    241
# 11             Symbolism    171

# %% [markdown]
# ### add class weight

# %%
genre_df['class_weight'] = genre_df.Count.sum() / (genre_df.shape[0] * genre_df.Count)
artists_genre =np.array(genre_df['genre'])  
artists_genre=np.unique(artists_genre)
class_weights = genre_df['class_weight'].to_dict()
class_weights
# Out:
# {0: 0.8400170648464164,
#  1: 1.1212984054669703,
#  2: 2.550518134715026,
#  3: 1.6353820598006645,
#  4: 0.3593065693430657,
#  5: 0.7238970588235294,
#  6: 2.7196132596685083,
#  7: 0.46970419847328243,
#  8: 1.593042071197411,
#  9: 1.2686855670103092,
#  10: 2.04253112033195,
#  11: 2.878654970760234}

# %% [markdown]
# ### check path

# %%
images_dir = 'image_dir'
artists_dirs = os.listdir(images_dir)

# %%
for name in artists_genre:
    if os.path.exists(os.path.join(images_dir, name)):
        print("Found -->", os.path.join(images_dir, name))
    else:
        print("Did not find -->", os.path.join(images_dir, name))
# Out:
# Found --> image_dir/Baroque
# Found --> image_dir/Cubism
# Found --> image_dir/Expressionism
# Found --> image_dir/High Renaissance
# Found --> image_dir/Impressionism
# Found --> image_dir/Northern Renaissance
# Found --> image_dir/Pop Art
# Found --> image_dir/Post-Impressionism
# Found --> image_dir/Primitivism
# Found --> image_dir/Romanticism
# Found --> image_dir/Surrealism
# Found --> image_dir/Symbolism

# %%
artists_temp = genre_df.copy()

# %% [markdown]
# ## data augmentation

# %%
# Augment data
batch_size = 16
img_height = 224
img_width = 224
train_input_shape = (224, 224, 3)
n_classes =len(artists_temp)

train_datagen = ImageDataGenerator(validation_split=0.2,
                                   rescale=1./255.,
                                   rotation_range=45,
                                   width_shift_range=0.5,
                                   height_shift_range=0.5,
                                   zoom_range=0.7,
                                   horizontal_flip=True,
                                   vertical_flip=True
                                  )

train_generator = train_datagen.flow_from_directory(directory=images_dir,
                                                    class_mode='categorical',
                                                    target_size=train_input_shape[0:2],
                                                    batch_size=batch_size,
                                                    subset="training",
                                                    shuffle=True,
                                                    classes=artists_genre.tolist()
                                                   )

valid_generator = train_datagen.flow_from_directory(directory=images_dir,
                                                    class_mode='categorical',
                                                    target_size=train_input_shape[0:2],
                                                    batch_size=batch_size,
                                                    subset="validation",
                                                    shuffle=True,
                                                    classes=artists_genre.tolist()
                                                   )

STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size
print("Total number of batches =", STEP_SIZE_TRAIN, "and", STEP_SIZE_VALID)
# Out:
# Found 4730 images belonging to 12 classes.
# Found 1177 images belonging to 12 classes.
# Total number of batches = 295 and 73

# %%
# Print a random paintings and it's random augmented version
col = 2
row = 4

fig, axes = plt.subplots(row, col, figsize=(10,15))


# Original image
for i in range(row):
    random_artist = random.choice(artists_genre)
    random_image = random.choice(os.listdir(os.path.join(images_dir, random_artist)))
    random_image_file = os.path.join(images_dir, random_artist, random_image)
    
    image = plt.imread(random_image_file)
    axes[i][0].imshow(image)
    axes[i][0].set_title("An original Image of " + random_artist.replace('_', ' '))
    axes[i][0].axis('off')

    # Transformed image
    aug_image = train_datagen.random_transform(image)
    axes[i][1].imshow(aug_image)
    axes[i][1].set_title("A transformed Image of " + random_artist.replace('_', ' '))
    axes[i][1].axis('off')

plt.show()

# %% [markdown]
# ## alexnet

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# 알렉스넷 모델 정의
def alexnet(input_shape, num_classes):
    model = models.Sequential()
    
    # 첫 번째 Convolutional Layer
    model.add(layers.Conv2D(96, kernel_size=(11, 11), strides=(4, 4), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
    model.add(layers.BatchNormalization())

    # 두 번째 Convolutional Layer
    model.add(layers.Conv2D(256, kernel_size=(5, 5), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
    model.add(layers.BatchNormalization())

    # 세 번째 Convolutional Layer
    model.add(layers.Conv2D(384, kernel_size=(3, 3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())

    # 네 번째 Convolutional Layer
    model.add(layers.Conv2D(384, kernel_size=(3, 3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())

    # 다섯 번째 Convolutional Layer
    model.add(layers.Conv2D(256, kernel_size=(3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
    model.add(layers.BatchNormalization())

    # Fully Connected Layer
    model.add(layers.Flatten())
    model.add(layers.Dense(2048, activation='relu'))
    model.add(layers.Dropout(0.5))

    model.add(layers.Dense(1024, activation='relu'))
    model.add(layers.Dropout(0.5))

    model.add(layers.Dense(n_classes, activation='softmax'))

    return model

model = alexnet(train_input_shape, n_classes)

# 모델 요약
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 54, 54, 96)        34944
#
#  max_pooling2d_3 (MaxPoolin  (None, 26, 26, 96)        0
#  g2D)
#
#  batch_normalization_5 (Bat  (None, 26, 26, 96)        384
#  chNormalization)
#
#  conv2d_6 (Conv2D)           (None, 26, 26, 256)       614656
#
#  max_pooling2d_4 (MaxPoolin  (None, 12, 12, 256)       0
#  g2D)
#
#  batch_normalization_6 (Bat  (None, 12, 12, 256)       1024
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 384)       885120
#
#  batch_normalization_7 (Bat  (None, 12, 12, 384)       1536
#  chNormalization)
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 384)       1327488
#
#  batch_normalization_8 (Bat  (None, 12, 12, 384)       1536
#  chNormalization)
#
#  conv2d_9 (Conv2D)           (None, 12, 12, 256)       884992
#
#  max_pooling2d_5 (MaxPoolin  (None, 5, 5, 256)         0
#  g2D)
#
#  batch_normalization_9 (Bat  (None, 5, 5, 256)         1024
#  chNormalization)
#
#  flatten_1 (Flatten)         (None, 6400)              0
#
#  dense_3 (Dense)             (None, 2048)              13109248
#
#  dropout_2 (Dropout)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 1024)              2098176
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_5 (Dense)             (None, 12)                12300
#
# =================================================================
# Total params: 18972428 (72.37 MB)
# Trainable params: 18969676 (72.36 MB)
# Non-trainable params: 2752 (10.75 KB)
# _________________________________________________________________

# %%
optimizer = AdamW(learning_rate=0.0001)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer, 
              metrics=['accuracy'])

# %%
n_epoch = 20

early_stop = EarlyStopping(monitor='val_loss', patience=5, verbose=1, 
                           mode='auto', restore_best_weights=True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, 
                              verbose=1, mode='auto')

# %%
history1 = model.fit(train_generator, steps_per_epoch=STEP_SIZE_TRAIN,
                              validation_data=valid_generator, validation_steps=STEP_SIZE_VALID,
                              epochs=n_epoch,
                              shuffle=True,
                              verbose=1,
                               use_multiprocessing=True,
                              callbacks=[reduce_lr],
                              workers=16,
                            class_weight=class_weights
                             )
# Out:
# Epoch 1/20
# 295/295 [==============================] - 79s 218ms/step - loss: 3.5350 - accuracy: 0.1521 - val_loss: 2.7610 - val_accuracy: 0.1096 - lr: 1.0000e-04
# Epoch 2/20
# 295/295 [==============================] - 66s 217ms/step - loss: 2.8505 - accuracy: 0.1759 - val_loss: 2.5913 - val_accuracy: 0.1010 - lr: 1.0000e-04
# Epoch 3/20
# 295/295 [==============================] - 65s 213ms/step - loss: 2.5239 - accuracy: 0.2026 - val_loss: 2.4717 - val_accuracy: 0.1670 - lr: 1.0000e-04
# Epoch 4/20
# 295/295 [==============================] - 65s 213ms/step - loss: 2.3944 - accuracy: 0.2230 - val_loss: 2.7039 - val_accuracy: 0.1301 - lr: 1.0000e-04
# Epoch 5/20
# 295/295 [==============================] - 65s 215ms/step - loss: 2.3516 - accuracy: 0.2283 - val_loss: 2.3513 - val_accuracy: 0.1704 - lr: 1.0000e-04
# Epoch 6/20
# 295/295 [==============================] - 65s 212ms/step - loss: 2.2980 - accuracy: 0.2370 - val_loss: 2.2865 - val_accuracy: 0.1455 - lr: 1.0000e-04
# Epoch 7/20
# 295/295 [==============================] - 64s 209ms/step - loss: 2.3035 - accuracy: 0.2261 - val_loss: 2.3256 - val_accuracy: 0.1892 - lr: 1.0000e-04
# Epoch 8/20
# 294/295 [============================>.] - ETA: 0s - loss: 2.2650 - accuracy: 0.2380
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 295/295 [==============================] - 64s 210ms/step - loss: 2.2658 - accuracy: 0.2374 - val_loss: 3.0783 - val_accuracy: 0.0933 - lr: 1.0000e-04
# Epoch 9/20
# 295/295 [==============================] - 65s 212ms/step - loss: 2.1467 - accuracy: 0.2605 - val_loss: 2.1739 - val_accuracy: 0.2680 - lr: 1.0000e-05
# Epoch 10/20
# 295/295 [==============================] - 65s 211ms/step - loss: 2.1354 - accuracy: 0.2724 - val_loss: 2.2101 - val_accuracy: 0.2560 - lr: 1.0000e-05
# Epoch 11/20
# 294/295 [============================>.] - ETA: 0s - loss: 2.1272 - accuracy: 0.2795
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 295/295 [==============================] - 66s 214ms/step - loss: 2.1262 - accuracy: 0.2792 - val_loss: 2.2100 - val_accuracy: 0.2654 - lr: 1.0000e-05
# Epoch 12/20
# 295/295 [==============================] - 66s 217ms/step - loss: 2.1143 - accuracy: 0.2773 - val_loss: 2.1814 - val_accuracy: 0.2603 - lr: 1.0000e-06
# Epoch 13/20
# 294/295 [============================>.] - ETA: 0s - loss: 2.0955 - accuracy: 0.2908
# Epoch 13: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 295/295 [==============================] - 65s 212ms/step - loss: 2.0935 - accuracy: 0.2908 - val_loss: 2.1824 - val_accuracy: 0.2688 - lr: 1.0000e-06
# Epoch 14/20
# 295/295 [==============================] - 65s 211ms/step - loss: 2.0825 - accuracy: 0.3027 - val_loss: 2.1845 - val_accuracy: 0.2731 - lr: 1.0000e-07
# Epoch 15/20
# 295/295 [==============================] - 64s 210ms/step - loss: 2.0973 - accuracy: 0.2944 - val_loss: 2.1624 - val_accuracy: 0.2783 - lr: 1.0000e-07
# Epoch 16/20
# 295/295 [==============================] - 59s 194ms/step - loss: 2.0827 - accuracy: 0.3031 - val_loss: 2.1767 - val_accuracy: 0.2723 - lr: 1.0000e-07
# Epoch 17/20
# 295/295 [==============================] - ETA: 0s - loss: 2.0981 - accuracy: 0.2800
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# 295/295 [==============================] - 65s 212ms/step - loss: 2.0981 - accuracy: 0.2800 - val_loss: 2.1683 - val_accuracy: 0.2705 - lr: 1.0000e-07
# Epoch 18/20
# 295/295 [==============================] - 65s 210ms/step - loss: 2.1126 - accuracy: 0.2849 - val_loss: 2.1554 - val_accuracy: 0.2825 - lr: 1.0000e-08
# Epoch 19/20
# 295/295 [==============================] - 65s 212ms/step - loss: 2.0940 - accuracy: 0.2857 - val_loss: 2.1745 - val_accuracy: 0.2568 - lr: 1.0000e-08
# Epoch 20/20
# 294/295 [============================>.] - ETA: 0s - loss: 2.0954 - accuracy: 0.2957
# Epoch 20: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
# 295/295 [==============================] - 64s 210ms/step - loss: 2.0938 - accuracy: 0.2957 - val_loss: 2.1778 - val_accuracy: 0.2577 - lr: 1.0000e-08

# %% [markdown]
# ## history

# %%
# Merge history1 and history2
history = {}
history['loss'] = history1.history['loss'] #+ history2.history['loss']
history['accuracy'] = history1.history['accuracy'] #+ history2.history['accuracy']
history['val_loss'] = history1.history['val_loss'] #+ history2.history['val_loss']
history['val_accuracy'] = history1.history['val_accuracy'] #+ history2.history['val_accuracy']
# history['learning_rate'] = history1.history['learning_rate'] + history2.history['learning_rate']

# %%
# Plot the training graph
def plot_training(history):
    acc = history['accuracy']
    val_acc = history['val_accuracy']
    loss = history['loss']
    val_loss = history['val_loss']
    epochs = range(len(loss))

    fig, axes = plt.subplots(1, 2, figsize=(15,5))
    
    axes[0].plot(epochs, acc, 'r-', label='Training Accuracy')
    axes[0].plot(epochs, val_acc, 'b--', label='Validation Accuracy')
    axes[0].set_title('Training and Validation Accuracy')
    axes[0].legend(loc='best')

    axes[1].plot(epochs, loss, 'r-', label='Training Loss')
    axes[1].plot(epochs, val_loss, 'b--', label='Validation Loss')
    axes[1].set_title('Training and Validation Loss')
    axes[1].legend(loc='best')
    
    plt.show()
    
plot_training(history)

# %% [markdown]
# ## result

# %%
# Prediction accuracy on train data
score = model.evaluate_generator(train_generator, verbose=1)
print("Prediction accuracy on train data =%.3f"%score[1])
# Out:
# /tmp/ipykernel_42/3410001329.py:2: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score = model.evaluate_generator(train_generator, verbose=1)
# 296/296 [==============================] - 90s 305ms/step - loss: 1.9829 - accuracy: 0.3590
# Prediction accuracy on train data =0.359

# %%
# Prediction accuracy on CV data
score = model.evaluate_generator(valid_generator, verbose=1)
print("Prediction accuracy on CV data =%.3f"%score[1])
# Out:
# /tmp/ipykernel_42/3290181623.py:2: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score = model.evaluate_generator(valid_generator, verbose=1)
# 74/74 [==============================] - 23s 307ms/step - loss: 2.1898 - accuracy: 0.2693
# Prediction accuracy on CV data =0.269

# %%
# Classification report and confusion matrix
from sklearn.metrics import *
import seaborn as sns

tick_labels = artists_genre

def showClassficationReport_Generator(model, valid_generator, STEP_SIZE_VALID):
    # Loop on each generator batch and predict
    y_pred, y_true = [], []
    for i in range(STEP_SIZE_VALID):
        (X,y) = next(valid_generator)
        y_pred.append(model.predict(X))
        y_true.append(y)
    
    # Create a flat list for y_true and y_pred
    y_pred = [subresult for result in y_pred for subresult in result]
    y_true = [subresult for result in y_true for subresult in result]
    
    # Update Truth vector based on argmax
    y_true = np.argmax(y_true, axis=1)
    y_true = np.asarray(y_true).ravel()
    
    # Update Prediction vector based on argmax
    y_pred = np.argmax(y_pred, axis=1)
    y_pred = np.asarray(y_pred).ravel()
    
    # Confusion Matrix
    fig, ax = plt.subplots(figsize=(10,10))
    conf_matrix = confusion_matrix(y_true, y_pred, labels=np.arange(n_classes))
    conf_matrix = conf_matrix/np.sum(conf_matrix, axis=1)
    sns.heatmap(conf_matrix, annot=True, fmt=".2f", square=True, cbar=False, 
                cmap=plt.cm.jet, xticklabels=tick_labels, yticklabels=tick_labels,
                ax=ax)
    ax.set_ylabel('Actual')
    ax.set_xlabel('Predicted')
    ax.set_title('Confusion Matrix')
    plt.show()
    
    print('Classification Report:')
    print(classification_report(y_true, y_pred, labels=np.arange(n_classes), target_names=artists_genre))

showClassficationReport_Generator(model, valid_generator, STEP_SIZE_VALID)
# Out:
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Classification Report:
#                       precision    recall  f1-score   support
#
#              Baroque       0.48      0.56      0.52       116
#               Cubism       0.27      0.03      0.06        86
#        Expressionism       0.29      0.39      0.34        38
#     High Renaissance       0.23      0.23      0.23        60
#        Impressionism       0.13      0.04      0.07       273
# Northern Renaissance       0.46      0.77      0.58       133
#              Pop Art       0.26      0.56      0.36        36
#   Post-Impressionism       0.35      0.27      0.30       207
#          Primitivism       0.07      0.05      0.06        61
#          Romanticism       0.35      0.17      0.23        77
#           Surrealism       0.12      0.19      0.15        47
#            Symbolism       0.06      0.38      0.11        34
#
#             accuracy                           0.28      1168
#            macro avg       0.26      0.30      0.25      1168
#         weighted avg       0.28      0.28      0.25      1168
